# %%
import pandas as pd
import numpy as np

# %%
sig1 = pd.read_csv('signals/s1.csv')

# %%
from matplotlib import pyplot as plt

# %%
sig1
# Out:
#              0
# 0     0.031002
# 1     0.063226
# 2     0.093798
# 3     0.124910
# 4     0.150260
# 5     0.170330
# 6     0.189190
# 7     0.199220
# 8     0.202450
# 9     0.200150
# 10    0.190010
# 11    0.175320
# 12    0.154280
# 13    0.130730
# 14    0.108040
# 15    0.082256
# 16    0.052169
# 17    0.021528
# 18   -0.007507
# 19   -0.043979
# 20   -0.076801
# 21   -0.103440
# 22   -0.127720
# 23   -0.156150
# 24   -0.176950
# 25   -0.194950
# 26   -0.208050
# 27   -0.219530
# 28   -0.227390
# 29   -0.243930
# ...        ...
# 5380 -0.216250
# 5381 -0.163760
# 5382 -0.109490
# 5383 -0.057302
# 5384 -0.000536
# 5385  0.054509
# 5386  0.108950
# 5387  0.162520
# 5388  0.208890
# 5389  0.251430
# 5390  0.293950
# 5391  0.334120
# 5392  0.364920
# 5393  0.393030
# 5394  0.415600
# 5395  0.432710
# 5396  0.448040
# 5397  0.458960
# 5398  0.463750
# 5399  0.471320
# 5400  0.469420
# 5401  0.460930
# 5402  0.442490
# 5403  0.414670
# 5404  0.376750
# 5405  0.337400
# ...

# %%
sig1.shape
# Out:
# (5410, 1)

# %%
plt.plot(sig1)

# %%
GT = pd.read_csv('GT.csv')

# %%
GT.head()
# Out:
#      S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0   515   540   504   508   479   584   555   581   636   515  ...    533
# 1   681   639   597   623   560   638   748   640   653   621  ...    671
# 2  1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3  1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4  1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
#
#     S22   S23   S24   S25   S26   S27   S28   S29   S30
# 0   598   525   538   293   486   903   480   450   351
# 1   818   639   607   427   636  1118   625   616   485
# 2  1362  1305  1158   808  1187  1580  1010  1022  1177
# 3  1426  1399  1250   955  1357  1932  1170  1151  1266
# 4  2263  2167  1854  1338  2195  2306  1737  1596  1389
#
# [5 rows x 30 columns]

# %%
plt.plot(sig1)
plt.scatter(GT.S1.values,sig1.loc[sig1.index.isin(GT.S1.values)], color = 'red')
plt.show()

# %%
for i in range(1,31):
    sig1['s'+str(i)]= pd.read_csv('signals/s'+str(i)+'.csv')

# %%
sig1.head()
# Out:
#           0        s1        s2        s3        s4        s5        s6  \
# 0  0.031002  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616
# 1  0.063226  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098
# 2  0.093798  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740
# 3  0.124910  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250
# 4  0.150260  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070
#
#          s7        s8        s9   ...          s21       s22       s23  \
# 0  0.047862  0.013715  0.049100   ...     0.052713  0.092918  0.034735
# 1  0.091393  0.009911  0.059151   ...     0.040028  0.116160  0.063616
# 2  0.120300 -0.003636  0.055854   ...     0.046161  0.107400  0.067167
# 3  0.130060 -0.025534  0.060223   ...     0.065851  0.112350  0.087296
# 4  0.121430 -0.046735  0.048627   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig=sig1.drop(columns=['0'])

# %%
sig.head()
# Out:
#          s1        s2        s3        s4        s5        s6        s7  \
# 0  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616  0.047862
# 1  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098  0.091393
# 2  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740  0.120300
# 3  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250  0.130060
# 4  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070  0.121430
#
#          s8        s9       s10   ...          s21       s22       s23  \
# 0  0.013715  0.049100  0.028074   ...     0.052713  0.092918  0.034735
# 1  0.009911  0.059151  0.050458   ...     0.040028  0.116160  0.063616
# 2 -0.003636  0.055854  0.043290   ...     0.046161  0.107400  0.067167
# 3 -0.025534  0.060223  0.045358   ...     0.065851  0.112350  0.087296
# 4 -0.046735  0.048627  0.054754   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
for i in range(1,31):
    plt.plot(sig['s'+str(i)])
    plt.scatter(GT['S'+str(i)].unique().tolist(),sig['s'+str(i)].loc[sig.index.isin(GT['S'+str(i)].values)], color = 'red')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-912a2a8a4c78> in <module>()
#       1 for i in range(1,31):
#       2     plt.plot(sig['s'+str(i)])
# ----> 3     plt.scatter(GT['S'+str(i)].unique().tolist(),sig['s'+str(i)].loc[sig.index.isin(GT['S'+str(i)].values)], color = 'red')
#       4     plt.show()
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
GT.shape
# Out:
# (20, 30)

# %%
GT
# Out:
#       S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0    515   540   504   508   479   584   555   581   636   515  ...    533
# 1    681   639   597   623   560   638   748   640   653   621  ...    671
# 2   1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3   1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4   1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
# 5   1722  1741  1695  1592  1641  1560  1839  2348  2166  2019  ...   1955
# 6   2282  2094  2046  1914  2030  2027  2298  2959  2625  2377  ...   2485
# 7   2374  2220  2131  2060  2105  2084  2485  3018  2811  2535  ...   2603
# 8   2721  2709  2601  2404  2540  2741  2940  3595  3366  3102  ...   3095
# 9   2831  2785  2676  2544  2620  2801  3150  3742  3605  3240  ...   3160
# 10  3121  3183  2904  2901  3168  3478  3570  4289  4177  3734  ...   3766
# ...

# %%
plt.plot(sig['s6'])
plt.scatter(GT['S6'].values,sig['s6'].loc[sig.index.isin(GT['S6'].values)], color = 'red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-83aaef147610> in <module>()
#       1 plt.plot(sig['s6'])
# ----> 2 plt.scatter(GT['S6'].values,sig['s6'].loc[sig.index.isin(GT['S6'].values)], color = 'red')
#       3 plt.show()
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
GT['S19'].unique()
# Out:
# array([ 516,  701, 1250, 1490, 2142, 2327, 2908, 3197, 3714, 3983, 4454,
#        4743, 5358, 5746, 6284, 6585])

# %%
sig['s19'].loc[sig.index.isin(GT['S19'].values)]
# Out:
# 516     0.296630
# 701    -0.040752
# 1250   -0.101470
# 1490   -0.030481
# 2142    0.152970
# 2327    0.087003
# 2908    0.202020
# 3197   -0.112220
# 3714   -0.037840
# 3983   -0.118610
# 4454    0.295080
# 4743    0.050278
# 5358    0.456100
# Name: s19, dtype: float64

# %%
a.shape
# Out:
# (13,)

# %%
GT.head()
# Out:
#      S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0   515   540   504   508   479   584   555   581   636   515  ...    533
# 1   681   639   597   623   560   638   748   640   653   621  ...    671
# 2  1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3  1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4  1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
#
#     S22   S23   S24   S25   S26   S27   S28   S29   S30
# 0   598   525   538   293   486   903   480   450   351
# 1   818   639   607   427   636  1118   625   616   485
# 2  1362  1305  1158   808  1187  1580  1010  1022  1177
# 3  1426  1399  1250   955  1357  1932  1170  1151  1266
# 4  2263  2167  1854  1338  2195  2306  1737  1596  1389
#
# [5 rows x 30 columns]

# %%
sig.head()
# Out:
#          s1        s2        s3        s4        s5        s6        s7  \
# 0  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616  0.047862
# 1  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098  0.091393
# 2  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740  0.120300
# 3  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250  0.130060
# 4  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070  0.121430
#
#          s8        s9       s10   ...          s21       s22       s23  \
# 0  0.013715  0.049100  0.028074   ...     0.052713  0.092918  0.034735
# 1  0.009911  0.059151  0.050458   ...     0.040028  0.116160  0.063616
# 2 -0.003636  0.055854  0.043290   ...     0.046161  0.107400  0.067167
# 3 -0.025534  0.060223  0.045358   ...     0.065851  0.112350  0.087296
# 4 -0.046735  0.048627  0.054754   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
GT.shape
# Out:
# (20, 30)

# %% [markdown]
# ## Preparing the dataset to be fed into model

# %%
y = np.zeros((30,5410))

# %%
# taking window at the end of the word = win
win = 20
for i in range(0,30):
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        for k in range(j+1,j+win+1):
            if k<5410:
                y[i,k]=1

# %%
y.shape
# Out:
# (30, 5410)

# %%
y[4,560]
# Out:
# 0.0

# %%
X = sig.values.T

# %%
X.shape
# Out:
# (30, 5410)

# %%
for i in range(30):
    plt.plot(y[i])
    plt.show()
# plotting for signal2 by setting the window size = 20

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size= 0.2 , random_state = 4)

# %%
x_test.shape
# Out:
# (6, 5410)

# %%
y_test.shape
# Out:
# (6, 5410)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## RNN Model

# %%
model = Sequential()

# %%
model.add(LSTM((1),batch_input_shape=(None,5410,1),return_sequences = True))

# %%
model.compile(loss = 'mean_absolute_error',optimizer = 'adam',metrics = ['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 5410, 1)           12
# ...
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, nb_epoch=10, batch_size=1, verbose=2,validation_data=(x_test, y_test))
# Out:
# /home/harsh/.conda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e71a5c7a6eda> in <module>()
# ----> 1 model.fit(x_train, y_train, nb_epoch=10, batch_size=1, verbose=2,validation_data=(x_test, y_test))
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
# ...

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, Masking, TimeDistributed, LSTM, Conv1D
from keras.layers import GRU, Bidirectional, BatchNormalization, Reshape
from keras.optimizers import Adam

# %%
# GRADED FUNCTION: model# GRADED 

def model(input_shape):
    """
    Function creating the model's graph in Keras.
    
    Argument:
    input_shape -- shape of the model's input data (using Keras conventions)

    Returns:
    model -- Keras model instance
    """
    
    X_input = Input(shape = input_shape)
    
    ### START CODE HERE ###
    
    # Step 1: CONV layer (≈4 lines)
    #X = Conv1D(196, kernel_size=15, strides=4)(X_input)                                 # CONV1D
    X = BatchNormalization()(X_input)                                 # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)

    # Step 2: First GRU Layer (≈4 lines)
    X = GRU(units = 1, return_sequences = False)(X) # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    
    # Step 3: Second GRU Layer (≈4 lines)
    X = GRU(units = 1, return_sequences = False)(X)   # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                  # Batch normalization
    X = Dropout(0.8)(X)                                  # dropout (use 0.8)
    
    # Step 4: Time-distributed dense layer (≈1 line)
    X = TimeDistributed(Dense(1, activation = "sigmoid"))(X) # time distributed  (sigmoid)

    ### END CODE HERE ###

    model = Model(inputs = X_input, outputs = X)
    
    return model

# %%
model = model(input_shape = (5410,))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7bfa5ad40566> in <module>()
# ----> 1 model = model(input_shape = (5410,))
#
# <ipython-input-52-153be038908d> in model(input_shape)
#      24
#      25     # Step 2: First GRU Layer (≈4 lines)
# ---> 26     X = GRU(units = 1, return_sequences = False)(X) # GRU (use 128 units and return the sequences)
#      27     X = Dropout(0.8)(X)                                 # dropout (use 0.8)
#      28     X = BatchNormalization()(X)                                 # Batch normalization
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     530
#     531         if initial_state is None and constants is None:
# --> 532             return super(RNN, self).__call__(inputs, **kwargs)
#     533
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 5410, 30)          0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5410, 30)          120
# _________________________________________________________________
# activation_2 (Activation)    (None, 5410, 30)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5410, 30)          0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 5410, 128)         61056
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5410, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5410, 128)         512
# ...

# %%
model.compile(loss = 'mean_absolute_error',optimizer = 'adam',metrics = ['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-da402dc18371> in <module>()
# ----> 1 model.compile(loss = 'mean_absolute_error',optimizer = 'adam',metrics = ['accuracy'])
#
# AttributeError: 'function' object has no attribute 'compile'

# %%
model.fit(x_train, y_train, nb_epoch=1, batch_size=5, verbose=2,validation_data=(x_test, y_test))
# Out:
# /home/harsh/.conda/envs/py35/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-6b904f62a38d> in <module>()
# ----> 1 model.fit(x_train, y_train, nb_epoch=1, batch_size=5, verbose=2,validation_data=(x_test, y_test))
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
# ...
