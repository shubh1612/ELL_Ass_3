# %%
import pandas as pd
import numpy as np

# %%
sig1 = pd.read_csv('signals/s1.csv')

# %%
from matplotlib import pyplot as plt

# %%
sig1.shape
# Out:
# (5410, 1)

# %%
plt.plot(sig1)

# %%
GT = pd.read_csv('GT.csv')

# %%
GT.head()
# Out:
#      S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0   515   540   504   508   479   584   555   581   636   515  ...    533
# 1   681   639   597   623   560   638   748   640   653   621  ...    671
# 2  1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3  1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4  1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
#
#     S22   S23   S24   S25   S26   S27   S28   S29   S30
# 0   598   525   538   293   486   903   480   450   351
# 1   818   639   607   427   636  1118   625   616   485
# 2  1362  1305  1158   808  1187  1580  1010  1022  1177
# 3  1426  1399  1250   955  1357  1932  1170  1151  1266
# 4  2263  2167  1854  1338  2195  2306  1737  1596  1389
#
# [5 rows x 30 columns]

# %%
plt.plot(sig1)
plt.scatter(GT.S1.values,sig1.loc[sig1.index.isin(GT.S1.values)], color = 'red')
plt.show()

# %%
for i in range(1,31):
    sig1['s'+str(i)]= pd.read_csv('signals/s'+str(i)+'.csv')

# %%
sig1.head()
# Out:
#           0        s1        s2        s3        s4        s5        s6  \
# 0  0.031002  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616
# 1  0.063226  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098
# 2  0.093798  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740
# 3  0.124910  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250
# 4  0.150260  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070
#
#          s7        s8        s9   ...          s21       s22       s23  \
# 0  0.047862  0.013715  0.049100   ...     0.052713  0.092918  0.034735
# 1  0.091393  0.009911  0.059151   ...     0.040028  0.116160  0.063616
# 2  0.120300 -0.003636  0.055854   ...     0.046161  0.107400  0.067167
# 3  0.130060 -0.025534  0.060223   ...     0.065851  0.112350  0.087296
# 4  0.121430 -0.046735  0.048627   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig=sig1.drop(columns=['0'])

# %%
sig.head()
# Out:
#          s1        s2        s3        s4        s5        s6        s7  \
# 0  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616  0.047862
# 1  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098  0.091393
# 2  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740  0.120300
# 3  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250  0.130060
# 4  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070  0.121430
#
#          s8        s9       s10   ...          s21       s22       s23  \
# 0  0.013715  0.049100  0.028074   ...     0.052713  0.092918  0.034735
# 1  0.009911  0.059151  0.050458   ...     0.040028  0.116160  0.063616
# 2 -0.003636  0.055854  0.043290   ...     0.046161  0.107400  0.067167
# 3 -0.025534  0.060223  0.045358   ...     0.065851  0.112350  0.087296
# 4 -0.046735  0.048627  0.054754   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
for i in range(1,31):
    plt.plot(sig['s'+str(i)])
    plt.scatter(GT['S'+str(i)].unique().tolist(),sig['s'+str(i)].loc[sig.index.isin(GT['S'+str(i)].values)], color = 'red')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-912a2a8a4c78> in <module>()
#       1 for i in range(1,31):
#       2     plt.plot(sig['s'+str(i)])
# ----> 3     plt.scatter(GT['S'+str(i)].unique().tolist(),sig['s'+str(i)].loc[sig.index.isin(GT['S'+str(i)].values)], color = 'red')
#       4     plt.show()
#
# ~/.conda/envs/py35/lib/python3.5/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3468                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3469                          linewidths=linewidths, verts=verts,
# -> 3470                          edgecolors=edgecolors, data=data, **kwargs)
#    3471     finally:
#    3472         ax._hold = washold
#
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
GT.shape
# Out:
# (20, 30)

# %%
GT
# Out:
#       S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0    515   540   504   508   479   584   555   581   636   515  ...    533
# 1    681   639   597   623   560   638   748   640   653   621  ...    671
# 2   1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3   1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4   1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
# 5   1722  1741  1695  1592  1641  1560  1839  2348  2166  2019  ...   1955
# 6   2282  2094  2046  1914  2030  2027  2298  2959  2625  2377  ...   2485
# 7   2374  2220  2131  2060  2105  2084  2485  3018  2811  2535  ...   2603
# 8   2721  2709  2601  2404  2540  2741  2940  3595  3366  3102  ...   3095
# 9   2831  2785  2676  2544  2620  2801  3150  3742  3605  3240  ...   3160
# 10  3121  3183  2904  2901  3168  3478  3570  4289  4177  3734  ...   3766
# ...

# %%
GT['S19'].unique()
# Out:
# array([ 516,  701, 1250, 1490, 2142, 2327, 2908, 3197, 3714, 3983, 4454,
#        4743, 5358, 5746, 6284, 6585])

# %%
sig['s19'].loc[sig.index.isin(GT['S19'].values)]
# Out:
# 516     0.296630
# 701    -0.040752
# 1250   -0.101470
# 1490   -0.030481
# 2142    0.152970
# 2327    0.087003
# 2908    0.202020
# 3197   -0.112220
# 3714   -0.037840
# 3983   -0.118610
# 4454    0.295080
# 4743    0.050278
# 5358    0.456100
# Name: s19, dtype: float64

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d74f1bcdd37c> in <module>()
# ----> 1 a.shape
#
# NameError: name 'a' is not defined

# %%
GT.head()
# Out:
#      S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...    S21  \
# 0   515   540   504   508   479   584   555   581   636   515  ...    533
# 1   681   639   597   623   560   638   748   640   653   621  ...    671
# 2  1047  1024   925   980  1078   900  1109  1329  1300  1212  ...   1109
# 3  1225  1154  1043  1062  1161   992  1274  1407  1359  1403  ...   1255
# 4  1559  1608  1373  1460  1572  1501  1658  2110  1994  1830  ...   1831
#
#     S22   S23   S24   S25   S26   S27   S28   S29   S30
# 0   598   525   538   293   486   903   480   450   351
# 1   818   639   607   427   636  1118   625   616   485
# 2  1362  1305  1158   808  1187  1580  1010  1022  1177
# 3  1426  1399  1250   955  1357  1932  1170  1151  1266
# 4  2263  2167  1854  1338  2195  2306  1737  1596  1389
#
# [5 rows x 30 columns]

# %%
sig.head()
# Out:
#          s1        s2        s3        s4        s5        s6        s7  \
# 0  0.031002  0.013865  0.087934  0.040046  0.017199  0.031616  0.047862
# 1  0.063226  0.096098  0.205090  0.087044  0.029640  0.070098  0.091393
# 2  0.093798  0.145510  0.330540  0.130460  0.042682  0.115740  0.120300
# 3  0.124910  0.168590  0.434670  0.168330  0.052158  0.157250  0.130060
# 4  0.150260  0.166830  0.520920  0.227040  0.057899  0.179070  0.121430
#
#          s8        s9       s10   ...          s21       s22       s23  \
# 0  0.013715  0.049100  0.028074   ...     0.052713  0.092918  0.034735
# 1  0.009911  0.059151  0.050458   ...     0.040028  0.116160  0.063616
# 2 -0.003636  0.055854  0.043290   ...     0.046161  0.107400  0.067167
# 3 -0.025534  0.060223  0.045358   ...     0.065851  0.112350  0.087296
# 4 -0.046735  0.048627  0.054754   ...     0.114810  0.125890  0.122860
#
#         s24      s25      s26      s27       s28       s29      s30
# ...

# %%
sig.shape
# Out:
# (5410, 30)

# %%
GT.shape
# Out:
# (20, 30)

# %% [markdown]
# ## Preparing the dataset to be fed into model

# %%
y = np.zeros((30,5410))

# %%
# taking window at the end of the word = win
win = 0
for i in range(0,30):
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*5410/5410)
        for k in range(x-win,x+win+1):
            if k<5410:
                y[i,k]=1

# %%
y.shape
# Out:
# (30, 5410)

# %%
y[4,560]
# Out:
# 1.0

# %%
X = sig.values.T

# %%
X.shape
# Out:
# (30, 5410)

# %%
X_no = np.nan_to_num(X)

# %%
for i in range(30):
    plt.plot(y[i])
    plt.show()
# plotting for signal2 by setting the window size = 20

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X_no,y,test_size= 0.2 , random_state = 4)

# %%
x_test.shape
# Out:
# (6, 5410)

# %%
y_test.shape
# Out:
# (6, 5410)

# %% [markdown]
# ## RNN Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, SimpleRNN
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Model, load_model, Sequential
from keras.layers import Dense, Activation, Dropout, Input, Masking, TimeDistributed, LSTM, Conv1D
from keras.layers import GRU, Bidirectional, BatchNormalization, Reshape
from keras.optimizers import Adam

# %%
from keras.layers import Reshape

# %%
x_train = x_train.reshape((24,5410,1))
y_train = y_train.reshape((24,5410,1))
x_test = x_test.reshape((6,5410,1))
y_test = y_test.reshape((6,5410,1))

# %% [markdown]
# ## LSTM(on 5410 timesteps)->sigmoid

# %%
model = Sequential()
#model.add(Conv1D(filters = 1, kernel_size = 15, strides = 4, input_shape=(1,5410)))
#model.add(Reshape((1,1349)))
model.add(LSTM(1,input_shape = (5410,1),return_sequences = True))
model.add(Dense(1, activation = 'sigmoid'))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])
model.fit(x_train,y_train,epochs = 1, batch_size = 24,verbose = 1, validation_data=(x_test,y_test))
# Out:
# Train on 24 samples, validate on 6 samples
# Epoch 1/1
# 24/24 [==============================] - 13s 535ms/step - loss: 0.6933 - acc: 0.5047 - val_loss: 0.6933 - val_acc: 0.5237

# %%
y_train_pred = model.predict(x_train)

# %%
y_train_pred.reshape((24,5410))
for i in range(24):
    plt.plot(y_train.reshape((24,5410))[i][2000:3000])
    plt.plot(y_train_pred[i][2000:3000])
    plt.show()

# %% [markdown]
# ## Using conv1d and batch normalisation:

# %%
yc = np.zeros((30,1349))
# taking window at the end of the word = win
win1 = 25
#win1 = int(1349*win/5490)
for i in range(0,30):
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*1349/5410)
        for k in range(x-win1,x+win1+1):
            if k<1349:
                yc[i,k]=1

# %%
Xz = ((X.T - np.nanmean(X.T, axis=0))/np.nanstd(X.T, axis=0)).T

# %%
Xz = np.nan_to_num(Xz)

# %%
Xz
# Out:
# array([[ 0.07883368,  0.18887793,  0.29328065, ...,  0.81915997,
#          0.66026103,  0.49722998],
#        [ 0.00533737,  0.31814912,  0.50611081, ...,  0.04760327,
#         -0.04770412, -0.1537484 ],
#        [ 0.36308726,  0.86885779,  1.41043409, ..., -0.6183293 ,
#         -0.65355658, -0.67725729],
#        ...,
#        [ 0.16554778,  0.57199213,  0.81981024, ...,  0.84132272,
#          0.70828501,  0.57774766],
#        [ 0.03057954,  0.00679414, -0.03716871, ...,  0.06484706,
#          0.15232483,  0.21960924],
#        [-0.95633894, -0.90309099, -0.84486626, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
x_train,x_test,y_train,y_test = train_test_split(Xz,yc,test_size= 0.2 , random_state = 11)
x_train = x_train.reshape((24,5410,1))
y_train = y_train.reshape((24,1349,1))
x_test = x_test.reshape((6,5410,1))
y_test = y_test.reshape((6,1349,1))

# %% [markdown]
# ## conv1d->LSTM->Sigmoid

# %%
def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
    # Step 1: CONV layer (≈4 lines)
    X = Conv1D(filters = 10, kernel_size = 15, strides = 4)(X_input)                                # CONV1D
    X =   BatchNormalization()(X)                               # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(5,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

# %% [markdown]
# ## conv->LSTM->LSTM->sigmoid(Time Distributed)

# %%
def model(input_shape):

    
    X_input = Input(shape = input_shape)
    
 
    
    # Step 1: CONV layer (≈4 lines)
    X = Conv1D(filters = 1, kernel_size = 15, strides = 4)(X_input)                                # CONV1D
    X =   BatchNormalization()(X)                               # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)

    # Step 2: First LSTM Layer (≈4 lines)
    X = LSTM(units = 1, return_sequences = True)(X)                                # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    
    # Step 3: Second LSTM Layer (≈4 lines)
    X = LSTM(units = 1, return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 4: Time-distributed dense layer (≈1 line)
    X = TimeDistributed(Dense(1, activation = "sigmoid"))(X) # time distributed  (sigmoid)



    model = Model(inputs = X_input, outputs = X)
    
    return model

# %%
model = model(input_shape = ( 5410,1))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         (None, 5410, 1)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 1349, 10)          160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1349, 10)          40
# _________________________________________________________________
# activation_4 (Activation)    (None, 1349, 10)          0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1349, 10)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1349, 5)           320
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1349, 5)           0
# ...

# %%
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])
model.fit(x_train,y_train,epochs = 1, batch_size =24 ,verbose = 1, validation_data=(x_test,y_test))
# Out:
# Train on 24 samples, validate on 6 samples
# Epoch 1/1
# 24/24 [==============================] - 3s 143ms/step - loss: 1.0579 - acc: 0.5080 - val_loss: 0.7208 - val_acc: 0.4865

# %%
y_train_pred = model.predict(x_train)
y_train_pred.reshape((24,1349))
for i in range(24):
    plt.plot(y_train.reshape((24,1349))[i])
    plt.scatter(np.arange(1349),y_train_pred[i])
    plt.show()

# %% [markdown]
# # Using variable sequence length

# %% [markdown]
# ## with convolution  This is the model

# %%
# step1: model
fil_size = 15    
stride = 4
no_fil=10
lstm_units = 2

def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
    # Step 1: CONV layer (≈4 lines)
    X = Conv1D(filters = no_fil, kernel_size = fil_size, strides = stride)(X_input)                                # CONV1D
    X =   BatchNormalization()(X)                               # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)

    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

model = model(input_shape = ( None,1))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])



# step2: get the x_train from csv files and generate y_train
for i in range(0,27):
    x_train= pd.read_csv('signals/s'+str(i+1)+'.csv').values.T
    x_train= np.nan_to_num(x_train)
    m = x_train.shape[1]
    x_train=x_train.reshape((1,m,1))

    shape = int(((m - fil_size)/stride)+1)
    yc = np.zeros((1,shape))
    # taking window at the end of the word = win
    win1 = 0
    #win1 = int(1349*win/5490)
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*shape/m)
        for k in range(x-win1,x+win1+1):
            if k<shape:
                yc[0,k]=1
    y_train= yc.reshape((1,shape,1))
# step3: generator for (x_train,y_train)
    
# step3: model.fit_generator
    model.fit(x_train,y_train, batch_size=1, epochs = 1 ,verbose = 1, )
# Out:
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 0.8032 - acc: 0.9155
# Epoch 1/1
# 1/1 [==============================] - 1s 731ms/step - loss: 0.7557 - acc: 0.9184
# Epoch 1/1
# 1/1 [==============================] - 1s 672ms/step - loss: 0.7848 - acc: 0.9126
# Epoch 1/1
# 1/1 [==============================] - 1s 935ms/step - loss: 0.7639 - acc: 0.9225
# Epoch 1/1
# 1/1 [==============================] - 1s 1000ms/step - loss: 0.7531 - acc: 0.9247
# Epoch 1/1
# 1/1 [==============================] - 1s 706ms/step - loss: 0.8088 - acc: 0.9249
# Epoch 1/1
# 1/1 [==============================] - 1s 712ms/step - loss: 0.7643 - acc: 0.9273
# Epoch 1/1
# 1/1 [==============================] - 1s 785ms/step - loss: 0.7916 - acc: 0.9220
# Epoch 1/1
# 1/1 [==============================] - 1s 1s/step - loss: 0.7843 - acc: 0.9177
# Epoch 1/1
# 1/1 [==============================] - 1s 995ms/step - loss: 0.7638 - acc: 0.9254
# Epoch 1/1
# ...

# %%
sig_no=12
x_test= pd.read_csv('signals/s'+str(sig_no)+'.csv').values.T
x_test= np.nan_to_num(x_test)
m = x_test.shape[1]
x_test=x_test.reshape((1,m,1))


shape = int(((m - fil_size)/stride)+1)
#shape = m
yc = np.zeros((1,shape))
    # taking window at the end of the word = win
win1 = 0
    #win1 = int(1349*win/5490)
gt_col = GT['S'+str(sig_no)]
for j in gt_col:
    x = int(j*shape/m)
    for k in range(x-win1,x+win1+1):
        if k<shape:
            yc[0,k]=1
y_test= yc.reshape((1,shape,1))

# %%
#y_pred=model.predict(x_test).reshape(m,)
y_pred=model.predict(x_test).reshape(shape,)

# %%
a=int(2500*shape/m)
b=int(4500*shape/m)
plt.plot(y_pred)
plt.plot(y_test.reshape(shape,))
#plt.plot(x_test.reshape(m,)[2500:4500])
plt.show()

for i in range(len(y_pred)):
    if y_pred[i]<=0.5:
        y_pred[i]=1
    else:
        y_pred[i]=0
df = pd.DataFrame(y_pred,columns = ['pred'])
df['actual']=y_test.reshape(shape,)
df.to_csv('s'+str(sig_no)+'.csv')
        
plt.plot(y_pred)
plt.plot(y_test.reshape(shape,))
plt.show()

# %%
# step1: model
fil_size = 15    
stride = 4
no_fil=10
lstm_units = 5

def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
    # Step 1: CONV layer (≈4 lines)
    X = Conv1D(filters = no_fil, kernel_size = fil_size, strides = stride)(X_input)                                # CONV1D
    X =   BatchNormalization()(X)                               # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

model = model(input_shape = ( None,1))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])



# step2: get the x_train from csv files and generate y_train
for i in range(0,27):
    x_train= pd.read_csv('signals/s'+str(i+1)+'.csv').values.T
    x_train= np.nan_to_num(x_train)
    m = x_train.shape[1]
    x_train=x_train.reshape((1,m,1))

    shape = int(((m - fil_size)/stride)+1)
    yc = np.zeros((1,shape))
    # taking window at the end of the word = win
    win1 = 0
    #win1 = int(1349*win/5490)
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*shape/m)
        for k in range(x-win1,x+win1+1):
            if k<shape:
                yc[0,k]=1
    y_train= yc.reshape((1,shape,1))
# step3: generator for (x_train,y_train)
    
# step3: model.fit_generator
    model.fit(x_train,y_train, batch_size=1, epochs = 1 ,verbose = 1, )
# Out:
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.0951 - acc: 0.7057
# Epoch 1/1
# 1/1 [==============================] - 1s 790ms/step - loss: 1.1318 - acc: 0.6416
# Epoch 1/1
# 1/1 [==============================] - 1s 707ms/step - loss: 1.1087 - acc: 0.6563
# Epoch 1/1
# 1/1 [==============================] - 1s 711ms/step - loss: 1.0406 - acc: 0.7310
# Epoch 1/1
# 1/1 [==============================] - 1s 743ms/step - loss: 1.0943 - acc: 0.7001
# Epoch 1/1
# 1/1 [==============================] - 1s 752ms/step - loss: 1.1249 - acc: 0.6416
# Epoch 1/1
# 1/1 [==============================] - 1s 722ms/step - loss: 1.0697 - acc: 0.6453
# Epoch 1/1
# 1/1 [==============================] - 1s 790ms/step - loss: 1.1414 - acc: 0.6271
# Epoch 1/1
# 1/1 [==============================] - 1s 728ms/step - loss: 1.1682 - acc: 0.7037
# Epoch 1/1
# 1/1 [==============================] - 1s 741ms/step - loss: 1.0173 - acc: 0.6370
# Epoch 1/1
# ...

# %% [markdown]
# ## without convolution

# %%
# step1: model
fil_size = 15    
stride = 4
no_fil=10
lstm_units = 5

def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
                            # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)               
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)               
    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

model = model(input_shape = ( None,1))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])



# step2: get the x_train from csv files and generate y_train
for i in range(0,27):
    x_train= pd.read_csv('signals/s'+str(i+1)+'.csv').values.T
    x_train= np.nan_to_num(x_train)
    m = x_train.shape[1]
    x_train=x_train.reshape((1,m,1))

    shape = m
    yc = np.zeros((1,shape))
    # taking window at the end of the word = win
    win1 = 0
    #win1 = int(1349*win/5490)
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*shape/m)
        for k in range(x-win1,x+win1+1):
            if k<shape:
                yc[0,k]=1
    y_train= yc.reshape((1,shape,1))
# step3: generator for (x_train,y_train)
    
# step3: model.fit_generator
    model.fit(x_train,y_train, batch_size=1, epochs = 1 ,verbose = 1, )
# Out:
# Epoch 1/1
# 1/1 [==============================] - 4s 4s/step - loss: 1.1153 - acc: 0.6778
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.0652 - acc: 0.6758
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 1.0777 - acc: 0.6622
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.0498 - acc: 0.6649
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.1022 - acc: 0.6634
# Epoch 1/1
# 1/1 [==============================] - 2s 2s/step - loss: 1.1334 - acc: 0.6677
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.1035 - acc: 0.6661
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 0.9022 - acc: 0.6718
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.1543 - acc: 0.6747
# Epoch 1/1
# 1/1 [==============================] - 3s 3s/step - loss: 1.0369 - acc: 0.6778
# Epoch 1/1
# ...

# %% [markdown]
# ## using fit_generator

# %%
# step1: model
fil_size = 5    
stride = 2
no_fil=10
lstm_units = 5

def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
    # Step 1: CONV layer (≈4 lines)
    X = Conv1D(filters = no_fil, kernel_size = fil_size, strides = stride)(X_input)                                # CONV1D
    X =   BatchNormalization()(X)                               # Batch normalization
    X = Activation('relu')(X)                                 # ReLu activation
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                      # dropout (use 0.8)
    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)  

    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X)                                 # GRU (use 128 units and return the sequences)
    #X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)  
    
    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

model = model(input_shape = ( None,1))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])



# step2: get the x_train from csv files and generate y_train
features = []
labels = []
for i in range(0,27):
    x_train= pd.read_csv('signals/s'+str(i+1)+'.csv').values.T
    x_train= np.nan_to_num(x_train)
    m = x_train.shape[1]
    x_train=x_train.reshape((1,m,1))
    features.append(x_train)

    shape = int(((m - fil_size)/stride)+1)
    yc = np.zeros((1,shape))
    # taking window at the end of the word = win
    win1 = 0
    #win1 = int(1349*win/5490)
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*shape/m)
        for k in range(x-win1,x+win1+1):
            if k<shape:
                yc[0,k]=1
    y_train= yc.reshape((1,shape,1))
    labels.append(y_train)

# step3: generator for (x_train,y_train)
def generator(features, labels):
    i = 0 
    while True:
        #for i in range(batch_size):
        ## choose random index in features
        #    index= random.choice(len(features),1)
        #    batch_features[i] = some_processing(features[index])
        #    batch_labels[i] = labels[index]
        c=features[i].shape
        v=labels[i].shape
        feat = features[i]
        lab = labels[i]
        i=i+1
        yield feat, lab
    
# step4: model.fit_generator
model.fit_generator(generator(features, labels), steps_per_epoch=1, epochs=27,verbose = 2)
# Out:
# Epoch 1/27
#  - 12s - loss: 1.0872 - acc: 0.6556
# Epoch 2/27
#  - 4s - loss: 1.0445 - acc: 0.6621
# Epoch 3/27
#  - 4s - loss: 1.0592 - acc: 0.6542
# Epoch 4/27
#  - 4s - loss: 1.0510 - acc: 0.6602
# Epoch 5/27
#  - 4s - loss: 1.0800 - acc: 0.6591
# Epoch 6/27
#  - 5s - loss: 1.0622 - acc: 0.6796
# Epoch 7/27
#  - 4s - loss: 1.0381 - acc: 0.6725
# Epoch 8/27
#  - 4s - loss: 1.0270 - acc: 0.6849
# Epoch 9/27
#  - 4s - loss: 1.0136 - acc: 0.6897
# Epoch 10/27
#  - 4s - loss: 1.0643 - acc: 0.6695
# Epoch 11/27
#  - 6s - loss: 1.0204 - acc: 0.6887
# Epoch 12/27
#  - 5s - loss: 1.0699 - acc: 0.6747
# Epoch 13/27
#  - 4s - loss: 1.0564 - acc: 0.6863
# Epoch 14/27
#  - 4s - loss: 1.0115 - acc: 0.6951
# Epoch 15/27
#  - 4s - loss: 1.0856 - acc: 0.6885
# Epoch 16/27
#  - 4s - loss: 1.0640 - acc: 0.6820
# Epoch 17/27
#  - 4s - loss: 1.0627 - acc: 0.6885
# Epoch 18/27
#  - 4s - loss: 1.0572 - acc: 0.6888
# Epoch 19/27
#  - 5s - loss: 1.0448 - acc: 0.6988
# Epoch 20/27
# ...

# %% [markdown]
# ### Testing

# %%
sig_no=12
x_test= pd.read_csv('signals/s'+str(sig_no)+'.csv').values.T
x_test= np.nan_to_num(x_test)
m = x_test.shape[1]
x_test=x_test.reshape((1,m,1))


shape = int(((m - fil_size)/stride)+1)
yc = np.zeros((1,shape))
    # taking window at the end of the word = win
win1 = 0
    #win1 = int(1349*win/5490)
gt_col = GT['S'+str(sig_no)]
for j in gt_col:
    x = int(j*shape/m)
    for k in range(x-win1,x+win1+1):
        if k<shape:
            yc[0,k]=1
y_test= yc.reshape((1,shape,1))

# %%
y_pred=model.predict(x_test).reshape(shape,)

# %%
a=int(2500*shape/m)
b=int(4500*shape/m)
plt.plot(y_pred[a:b])
plt.plot(y_test.reshape(shape,)[a:b])
#plt.plot(x_test.reshape(m,)[2500:4500])
plt.show()

for i in range(len(y_pred)):
    if y_pred[i]<=0.5:
        y_pred[i]=0
    else:
        y_pred[i]=1
        
plt.plot(y_pred[a:b])
plt.plot(y_test.reshape(shape,)[a:b])
plt.show()

print('f1 score and accuracy',metrics.f1_score(y_pred,y_test.reshape(shape,1)),metrics.accuracy_score(y_pred,y_test.reshape(shape,1)))
# Out:
# f1 score and accuracy 0.018709995076317085 0.3766030653737879

# %%
plt.plot(y_pred)
plt.plot(y_test.reshape(shape,))
plt.show()

# %%
for i in range(len(y_pred)):
    if y_pred[i]<=0.5:
        y_pred[i]=0
    else:
        y_pred[i]=1

# %%
plt.plot(y_pred)
plt.plot(y_test.reshape(shape,))
plt.show()

# %%
from sklearn import metrics

# %%
print('f1 score and accuracy',metrics.f1_score(y_pred,y_test.reshape(shape,1)),metrics.accuracy_score(y_pred,y_test.reshape(shape,1)))
# Out:
# f1 score and accuracy 0.0 0.92087785157378

# %% [markdown]
# ## NO CONV only LSTM layers

# %%
# step1: model
fil_size = 0    
stride = 0
no_fil=0
lstm_units = 5

def model(input_shape):

    
    X_input = Input(shape = input_shape)
    

    
    # Step 2: Second RNN Layer (≈4 lines)
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)               
    X = LSTM(lstm_units,return_sequences = True)(X_input)                                 # GRU (use 128 units and return the sequences)
    X = Dropout(0.8)(X)                                 # dropout (use 0.8)
    X = BatchNormalization()(X)                                 # Batch normalization
    X = Dropout(0.8)(X)               
    # Step 3: dense layer (≈1 line)
    X = Dense(1, activation = "sigmoid")(X) # time distributed  (sigmoid)
    
    model = Model(inputs = X_input, outputs = X)
    
    return model

model = model(input_shape = ( None,1))
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, decay=0.01)
model.compile(loss = 'binary_crossentropy', optimizer= opt,metrics = ['accuracy'])



# step2: get the x_train from csv files and generate y_train
features = []
labels = []
for i in range(0,27):
    x_train= pd.read_csv('signals/s'+str(i+1)+'.csv').values.T
    x_train= np.nan_to_num(x_train)
    m = x_train.shape[1]
    x_train=x_train.reshape((1,m,1))
    features.append(x_train)

    shape = m
    yc = np.zeros((1,shape))
    # taking window at the end of the word = win
    win1 = 0
    #win1 = int(1349*win/5490)
    gt_col = GT['S'+str(i+1)]
    for j in gt_col:
        x = int(j*shape/m)
        for k in range(x-win1,x+win1+1):
            if k<shape:
                yc[0,k]=1
    y_train= yc.reshape((1,shape,1))
    labels.append(y_train)

# step3: generator for (x_train,y_train)
def generator(features, labels):
    i = 0 
    while True:
        #for i in range(batch_size):
        ## choose random index in features
        #    index= random.choice(len(features),1)
        #    batch_features[i] = some_processing(features[index])
        #    batch_labels[i] = labels[index]
        c=features[i].shape
        v=labels[i].shape
        feat = features[i]
        lab = labels[i]
        i=i+1
        yield feat, lab
    
# step4: model.fit_generator
model.fit_generator(generator(features, labels), steps_per_epoch=1, epochs=27,verbose=2)
# Out:
# Epoch 1/27
#  - 13s - loss: 0.9091 - acc: 0.4226
# Epoch 2/27
#  - 3s - loss: 0.8902 - acc: 0.5718
# Epoch 3/27
#  - 2s - loss: 0.8616 - acc: 0.4236
# Epoch 4/27
#  - 3s - loss: 0.8625 - acc: 0.5166
# Epoch 5/27
#  - 3s - loss: 0.9010 - acc: 0.5609
# Epoch 6/27
#  - 3s - loss: 0.8951 - acc: 0.4801
# Epoch 7/27
#  - 3s - loss: 0.8755 - acc: 0.5547
# Epoch 8/27
#  - 3s - loss: 0.8121 - acc: 0.6102
# Epoch 9/27
#  - 3s - loss: 0.9033 - acc: 0.4708
# Epoch 10/27
#  - 3s - loss: 0.8618 - acc: 0.4881
# Epoch 11/27
#  - 3s - loss: 0.9139 - acc: 0.5708
# Epoch 12/27
#  - 3s - loss: 0.9039 - acc: 0.5002
# Epoch 13/27
#  - 3s - loss: 0.9170 - acc: 0.4909
# Epoch 14/27
#  - 3s - loss: 0.8995 - acc: 0.4795
# Epoch 15/27
#  - 3s - loss: 0.8800 - acc: 0.4871
# Epoch 16/27
#  - 2s - loss: 0.9217 - acc: 0.4895
# Epoch 17/27
#  - 3s - loss: 0.8866 - acc: 0.4851
# Epoch 18/27
#  - 3s - loss: 0.9224 - acc: 0.4751
# Epoch 19/27
#  - 3s - loss: 0.8849 - acc: 0.5931
# Epoch 20/27
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_49 (InputLayer)        (None, None, 1)           0
# _________________________________________________________________
# lstm_68 (LSTM)               (None, None, 5)           140
# _________________________________________________________________
# dropout_128 (Dropout)        (None, None, 5)           0
# _________________________________________________________________
# batch_normalization_90 (Batc (None, None, 5)           20
# _________________________________________________________________
# dropout_129 (Dropout)        (None, None, 5)           0
# _________________________________________________________________
# dense_50 (Dense)             (None, None, 1)           6
# ...
# Total params: 166
# Trainable params: 156
# Non-trainable params: 10
# _________________________________________________________________

# %%
sig_no=12
x_test= pd.read_csv('signals/s'+str(sig_no)+'.csv').values.T
x_test= np.nan_to_num(x_test)
m = x_test.shape[1]
x_test=x_test.reshape((1,m,1))


shape = m
yc = np.zeros((1,shape))
    # taking window at the end of the word = win
win1 = 0
    #win1 = int(1349*win/5490)
gt_col = GT['S'+str(sig_no)]
for j in gt_col:
    x = int(j*shape/m)
    for k in range(x-win1,x+win1+1):
        if k<shape:
            yc[0,k]=1
y_test= yc.reshape((1,shape,1))

# %%
y_pred=model.predict(x_test).reshape(shape,)

# %%
plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
#plt.plot(x_test.reshape(shape,)[2500:4500])
plt.show()
#plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
plt.plot(x_test.reshape(shape,)[2500:4500])
plt.show()

for i in range(len(y_pred)):
    if y_pred[i]<=0.5:
        y_pred[i]=0
    else:
        y_pred[i]=1
        
plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
plt.show()

print('f1 score and accuracy',metrics.f1_score(y_pred,y_test.reshape(shape,1)),metrics.accuracy_score(y_pred,y_test.reshape(shape,1)))
# Out:
# f1 score and accuracy 0.010764262648008612 0.42535563545411914

# %%
plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
#plt.plot(x_test.reshape(shape,)[2500:4500])
plt.show()
plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
plt.plot(x_test.reshape(shape,)[2500:4500])
plt.show()

for i in range(len(y_pred)):
    if y_pred[i]<=0.5:
        y_pred[i]=0
    else:
        y_pred[i]=1
        
plt.plot(y_pred[2500:4500])
plt.plot(y_test.reshape(shape,)[2500:4500])
plt.show()

print('f1 score and accuracy',metrics.f1_score(y_pred,y_test.reshape(shape,1)),metrics.accuracy_score(y_pred,y_test.reshape(shape,1)))
# Out:
# f1 score and accuracy 0.010838562464346835 0.45787087697358136

# %% [markdown]
# ## multiple lstm layers

# %%
lengths=[]
for i in range(30):
    length= pd.read_csv('signals/s'+str(i+1)+'.csv').shape[0]
    lengths.append(length)

# %%
plt.hist(lengths)
plt.ylabel('No of signals')
plt.xlabel('No of time-steps')
plt.show()
